# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ruta = 'all_pokemon/all_pokemon.json'
data = pd.read_json(ruta)
data.head()
# Out:
#                          abilities  base_experience  \
# 0          [overgrow, chlorophyll]             64.0
# 1          [overgrow, chlorophyll]            142.0
# 2                      [shed-skin]             72.0
# 3  [soundproof, static, aftermath]            172.0
# 4                [tablets-of-ruin]            285.0
#
#                                                cries  \
# 0  {'latest': 'https://raw.githubusercontent.com/...
# 1  {'latest': 'https://raw.githubusercontent.com/...
# 2  {'latest': 'https://raw.githubusercontent.com/...
# 3  {'latest': 'https://raw.githubusercontent.com/...
# 4  {'latest': 'https://raw.githubusercontent.com/...
#
#                                                forms  \
# 0  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1  [{'name': 'ivysaur', 'url': 'https://pokeapi.c...
# 2  [{'name': 'metapod', 'url': 'https://pokeapi.c...
# 3  [{'name': 'electrode', 'url': 'https://pokeapi...
# 4  [{'name': 'wo-chien', 'url': 'https://pokeapi....
#
# ...

# %%
data.columns
# Out:
# Index(['abilities', 'base_experience', 'cries', 'forms', 'game_indices',
#        'height', 'held_items', 'id', 'is_default', 'location_area_encounters',
#        'moves', 'name', 'order', 'past_abilities', 'past_types', 'species',
#        'sprites', 'stats', 'types', 'weight', 'ranking', 'popularity'],
#       dtype='object')

# %%
data['stats']
# Out:
# 0       {'hp': 45, 'attack': 49, 'defense': 49, 'speci...
# 1       {'hp': 60, 'attack': 62, 'defense': 63, 'speci...
# 2       {'hp': 50, 'attack': 20, 'defense': 55, 'speci...
# 3       {'hp': 60, 'attack': 50, 'defense': 70, 'speci...
# 4       {'hp': 85, 'attack': 85, 'defense': 100, 'spec...
#                               ...
# 1024    {'hp': 65, 'attack': 75, 'defense': 45, 'speci...
# 1025    {'hp': 90, 'attack': 95, 'defense': 66, 'speci...
# 1026    {'hp': 115, 'attack': 145, 'defense': 92, 'spe...
# 1027    {'hp': 45, 'attack': 30, 'defense': 70, 'speci...
# 1028    {'hp': 87, 'attack': 60, 'defense': 95, 'speci...
# Name: stats, Length: 1029, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1029 entries, 0 to 1028
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   abilities                 1028 non-null   object
#  1   base_experience           1028 non-null   float64
#  2   cries                     1028 non-null   object
#  3   forms                     1028 non-null   object
#  4   game_indices              1028 non-null   object
#  5   height                    1028 non-null   float64
#  6   held_items                1028 non-null   object
#  7   id                        1028 non-null   float64
#  8   is_default                1028 non-null   float64
#  9   location_area_encounters  1028 non-null   object
#  10  moves                     1028 non-null   object
#  11  name                      1028 non-null   object
#  12  order                     1028 non-null   float64
# ...
