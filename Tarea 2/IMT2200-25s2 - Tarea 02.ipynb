# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# # <h1><center>Tarea 02: Extracción y Transformación de Datos </center></h1>
#
# **Fecha de Entrega:** 25 de septiembre de 2025, a las 23:59.
#
# **Fecha de publicación**: 2 de septiembre de 2025.
#
# **Formato de entrega:** Notebook ejecutado y comentado (`.ipynb`) en el módulo de Tarea 02 habilitado en Canvas.

# %% [markdown]
# ## Instrucciones
#
# - Esta Tarea debe desarrollarse de manera totalmente *individual*, de acuerdo a lo establecido en la sección de Integridad Académica en el programa del curso.
# - La Tarea debe ser desarrollada en lenguaje de programación Python y la entrega en formato Jupyter Notebook.
# - El desarrollo del Notebook debe ser claro y ordenado, incluyendo anotaciones (markdown) y comentarios que permitan seguir fácilmente el código y los pasos implementados a los correctores, y siguiendo buenas prácticas de programación. La presentación y claridad del notebook y código forman parte de la evaluación de la tarea.
# - Notebook **autocontenible** que:
#    - Ejecute sin errores todas las celdas.
#   - Contenga tanto el código como los comentarios y explicaciones necesarias.
#   - Incluya visualizaciones claras y correctamente etiquetadas.
# - No se aceptarán notebooks con celdas rotas o que dependan de rutas externas no indicadas en la tarea.
#
# - Deben hacer sus consultas y comentarios sobre la Tarea a través del canal de Tareas en el Foro del curso en Canvas.

# %% [markdown]
# ## 1. Objetivos
#
# - Aplicar los conceptos iniciales de manejo de datos y análisis exploratorio vistos en clases.
# - Practicar la lectura, limpieza y manipulación de datos en Python.
# - Desarrollar habilidades para visualizar y describir patrones y tendencias en conjuntos de datos reales.
# - Fomentar la capacidad de comunicar resultados de forma clara y fundamentada.
#
# ### 1.1 Objetivo educacional
#
# Esta Tarea tiene como objetivo que los estudiantes desarrollen la capacidad de manejar algunas de las librerías centrales para el desarrollo de Ciencia de Datos, con foco en la lectura y exploración de datos.
#
# Para los ejercicios a continuación, usted deberá leer, inspeccionar, manipular y graficar conjuntos de datos en distintos formatos, de manera de responder las preguntas de cada parte de la Tarea.
#
# ### 1.2 Pregunta de ciencia de datos
#
# Para esta tarea, queremos comprender y visualizar la distribución de aves migratorias en el territorio chileno. Específicamente, queremos entender las diferencias entre las migraciones de 2 especies en particular, el run-run y la dormilona tontita, a partir de los avistamientos registrados en eBird durante un periodo de 3 años y medio.
#
# ### 1.3 Recomendaciones
# - Utiliza las librerías sugeridas en el notebook o justifica brevemente si incorporas otras.
# - Revisa que todas las celdas se ejecuten en orden, desde el inicio, sin errores.
# - Comenta tu código para explicar qué hace cada sección relevante.
# - Asegúrate de que las visualizaciones sean fáciles de interpretar y tengan títulos y etiquetas adecuados.

# %% [markdown]
# ### 1.4 Ejemplo de visualización
#
# Esta tarea se enfoca en datos de aves. Para complementarla, les compartimos la siguiente página web, llamada "Bird Migration Explorer" que les permite visualizar, de una forma novedosa e interesante, las rutas de migración de aves en las Americas. Visiten la página para que vean cómo se puede visualizar datos de una manera interesante y novedosa, que podría ustedes usar en el futuro para sus proyectos.

# %%
from IPython.display import IFrame
IFrame("https://explorer.audubon.org/home?layersPanel=expand", width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="https://explorer.audubon.org/home?layersPanel=expand"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 2. Datos
#
# Los datos a utilizar provienen de la plataforma **[eBird](https://ebird.org/)**, una aplicación desarrollada por The Cornell Lab of Ornithology que permite a sus usuarios registrar y compartir avistamientos de aves en todo el mundo. La plataforma dispone de una API mediante la cual se pueden realizar consultas sobre avistamientos de aves recientes e históricos, especies según región, taxonomía, entre otros.
#
# ### 2.1 Acceso a la API
#
# Muchas API pueden utilizarse solo mediante el uso de una clave única, o "API key". Para conseguir una API key en eBird, primero debe ser usuario de la plataforma. Puede crear una cuenta aquí: https://secure.birds.cornell.edu/identity/account/create
#
#
# Con una cuenta ya creada, puede ingresar a https://ebird.org/api/keygen para generar su llave. Debe llenar un formulario de solicitud al pedir su llave. Como sugerencia, puede llenar los campos con la siguiente información:
#
# * **Organización:** Pontificia Universidad Católica de Chile
# * **Título del Proyecto:** Tarea IMT2200 Introducción a Ciencia de Datos
# * **Descripción:** "Uso educativo para exploración y análisis de distribución de aves migratorias en Chile."
# * **Tipo de Proyecto:** Academic/Student
# * **Casos de uso:** Materiales educativos y artíticos (...)
#
# Debería recibir su llave inmediatamente después de enviar su solicitud. Como recomendación, puede revisar la documentación de la API en el siguiente link: https://documenter.getpostman.com/view/664302/S1ENwy59#intro
#
# #### 2.2 Mapoteca de BCN
#
# Para esta tarea queremos visualizar el movimiento de aves a lo largo de nuestro país. Para ello, también necesitaremos manejar datos geoespaciales: específicamente, trabajaremos con un mapa vectorial de Chile disponible en la página web de la Biblioteca del Congreso Nacional: https://www.bcn.cl/siit/mapas_vectoriales/index_html
#
# Descargue el archivo `.zip` para las **Divisiones regionales** y descomprímalo. Dentro de esta carpeta, habrá un archivo llamado `Regional.shp`, que utilizaremos con `geopandas` para graficar nuestro mapa de Chile.

# %% [markdown]
# ### 2.3 Librerías
#
# Para esta tarea recomendamos al menos usar las librerías indicadas en la siguiente celda del Notebook. Puede agregar otras si lo estima conveniente para responder de mejor forma las preguntas de la Tarea.

# %%
import requests
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# ## 3. Desarrollo
#
# Para cada una de las siguientes preguntas o actividades incluya una o más celdas de código y Markdown con las respuestas o comentarios necesarios para contestar la pregunta o lograr la actividad. Agregue sus celdas a continuación de cada pregunta para que el Notebook quede ordenado.
#
# En el caso de gráficos, figuras o tablas, asegúrese que todas tengan título, etiquetas en los ejes o haya claridad de los contenidos.
#
# ### 3.1 Extracción de datos (1.5 puntos)
#
# **(1 pto)** Vamos a crear nuestra base de datos con los avistamientos registrados en eBird dentro de Chile desde 2022 hasta 2025. Revise la documentación de la API y averigue cómo extraer los avistamientos de un día. Luego extraiga los avistamientos para todos los días desde el **1 de enero de 2022 hasta el 31 de julio de 2025.** Cuando haya logrado extraer todos los datos, guárdelos en un archivo CSV o parquet.
#
# Responda:
#
# **a) (0.2 pts)** ¿Cuántos avistamientos tiene su dataset?
#
# **b) (0.3 pts)** Obtenga la cantidad de veces que se repite cada especie en su dataset y ordénelas de mayor a menor. ¿Qué pasa con la cantidad de avistamientos según especie? ¿Por qué?
#
# **Recomendaciones:**
# * Puede usar la librería `datetime` para generar fechas: cree una lista con todas las fechas e itere sobre esta lista para hacer los llamados a la API.
# * **Pruebe primero con uno o dos días** para verificar el funcionamiento de su código y de la API.
# * Inspeccione la forma en la que vienen los datos.
# * Vaya guardando los datos extraídos en archivos (CSV o parquet), de modo que no tenga que repetir los llamados en caso de algún error.
#
# **Hint**: Los códigos regionales chilenos para la API son los siguientes,
# * `regionCode = CL`
# * `sppLocale = es_CL` (para obtener nombres chilenos de las aves)

# %%
url = "https://api.ebird.org/v2/data/obs/CL/recent"
header = {'X-eBirdApiToken': 'ui2a8vmdt81j'}

# %%
respuesta = requests.get(url,headers=header)
respuesta.json()
# Out:
# [{'speciesCode': 'burowl',
#   'comName': 'Burrowing Owl',
#   'sciName': 'Athene cunicularia',
#   'locId': 'L9851416',
#   'locName': 'Centro de Humedales Río Cruces',
#   'obsDt': '2025-09-05 19:58',
#   'howMany': 1,
#   'lat': -39.7948417,
#   'lng': -73.2527175,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271670432'},
#  {'speciesCode': 'brnowl',
#   'comName': 'American Barn Owl',
#   'sciName': 'Tyto furcata',
#   'locId': 'L41284535',
#   'locName': 'S-40, Carahue, Araucanía, CL (-38.705, -73.227)',
#   'obsDt': '2025-09-05 19:49',
#   'howMany': 1,
#   'lat': -38.7054886,
#   'lng': -73.2265078,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271670078'},
#  {'speciesCode': 'austhr1',
#   'comName': 'Austral Thrush',
#   'sciName': 'Turdus falcklandii',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 1,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'thtray1',
#   'comName': 'Thorn-tailed Rayadito',
#   'sciName': 'Aphrastura spinicauda',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 1,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'wrlrus1',
#   'comName': 'Wren-like Rushbird',
#   'sciName': 'Phleocryptes melanops',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 2,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'plurai1',
#   'comName': 'Plumbeous Rail',
#   'sciName': 'Pardirallus sanguinolentus',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 1,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'bkfibi1',
#   'comName': 'Black-faced Ibis',
#   'sciName': 'Theristicus melanopis',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 7,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'soulap1',
#   'comName': 'Southern Lapwing',
#   'sciName': 'Vanellus chilensis',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 2,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'greegr',
#   'comName': 'Great Egret',
#   'sciName': 'Ardea alba',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 1,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'whimbr',
#   'comName': 'Whimbrel',
#   'sciName': 'Numenius phaeopus',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 1,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'yebtea1',
#   'comName': 'Yellow-billed Teal',
#   'sciName': 'Anas flavirostris',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 2,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'chicar1',
#   'comName': 'Chimango Caracara',
#   'sciName': 'Daptrius chimango',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 18:54',
#   'howMany': 1,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271663014'},
#  {'speciesCode': 'bcnher',
#   'comName': 'Black-crowned Night Heron',
#   'sciName': 'Nycticorax nycticorax',
#   'locId': 'L3939991',
#   'locName': 'Universidad Austral de Chile',
#   'obsDt': '2025-09-05 18:45',
#   'howMany': 2,
#   'lat': -39.808327,
#   'lng': -73.2525909,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664385'},
#  {'speciesCode': 'hrshaw',
#   'comName': "Harris's Hawk",
#   'sciName': 'Parabuteo unicinctus',
#   'locId': 'L22420581',
#   'locName': 'Humedal Carriel Norte',
#   'obsDt': '2025-09-05 18:43',
#   'howMany': 1,
#   'lat': -36.7685619,
#   'lng': -73.0796404,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271665015'},
#  {'speciesCode': 'kelgul',
#   'comName': 'Kelp Gull',
#   'sciName': 'Larus dominicanus',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 1,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504'},
#  {'speciesCode': 'grbfir1',
#   'comName': 'Green-backed Firecrown',
#   'sciName': 'Sephanoides sephaniodes',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 4,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504'},
#  {'speciesCode': 'yebpin1',
#   'comName': 'Yellow-billed Pintail',
#   'sciName': 'Anas georgica',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 2,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504'},
#  {'speciesCode': 'chiswa1',
#   'comName': 'Chilean Swallow',
#   'sciName': 'Tachycineta leucopyga',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 4,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504'},
#  {'speciesCode': 'chipig2',
#   'comName': 'Chilean Pigeon',
#   'sciName': 'Patagioenas araucana',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 6,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504'},
#  {'speciesCode': 'dabcin1',
#   'comName': 'Dark-bellied Cinclodes',
#   'sciName': 'Cinclodes patagonicus',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 1,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504'},
#  {'speciesCode': 'houspa',
#   'comName': 'House Sparrow',
#   'sciName': 'Passer domesticus',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 6,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504',
#   'exoticCategory': 'N'},
#  {'speciesCode': 'tuttyr1',
#   'comName': 'Tufted Tit-Tyrant',
#   'sciName': 'Anairetes parulus',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 1,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504'},
#  {'speciesCode': 'blcsis2',
#   'comName': 'Black-chinned Siskin',
#   'sciName': 'Spinus barbatus',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 2,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504'},
#  {'speciesCode': 'categr1',
#   'comName': 'Western Cattle-Egret',
#   'sciName': 'Ardea ibis',
#   'locId': 'L52476594',
#   'locName': 'Parque Isla Municipal',
#   'obsDt': '2025-09-05 18:40',
#   'howMany': 10,
#   'lat': -38.987275,
#   'lng': -72.61762,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271665504'},
#  {'speciesCode': 'bcbeag1',
#   'comName': 'Black-chested Buzzard-Eagle',
#   'sciName': 'Geranoaetus melanoleucus',
#   'locId': 'L6322110',
#   'locName': 'Cerro Calán',
#   'obsDt': '2025-09-05 18:29',
#   'howMany': 1,
#   'lat': -33.3978585,
#   'lng': -70.537076,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271659531'},
#  {'speciesCode': 'commin1',
#   'comName': 'Common Miner',
#   'sciName': 'Geositta cunicularia',
#   'locId': 'L5458420',
#   'locName': 'Estancia Yerba Buena',
#   'obsDt': '2025-09-05 18:24',
#   'howMany': 3,
#   'lat': -29.5729946,
#   'lng': -71.299682,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271659708'},
#  {'speciesCode': 'lotmea1',
#   'comName': 'Long-tailed Meadowlark',
#   'sciName': 'Leistes loyca',
#   'locId': 'L5458420',
#   'locName': 'Estancia Yerba Buena',
#   'obsDt': '2025-09-05 18:24',
#   'howMany': 2,
#   'lat': -29.5729946,
#   'lng': -71.299682,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271659708'},
#  {'speciesCode': 'gyhsif1',
#   'comName': 'Gray-hooded Sierra Finch',
#   'sciName': 'Phrygilus gayi',
#   'locId': 'L5458420',
#   'locName': 'Estancia Yerba Buena',
#   'obsDt': '2025-09-05 18:24',
#   'howMany': 2,
#   'lat': -29.5729946,
#   'lng': -71.299682,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271659708'},
#  {'speciesCode': 'rebhaw2',
#   'comName': 'Variable Hawk',
#   'sciName': 'Geranoaetus polyosoma',
#   'locId': 'L5458420',
#   'locName': 'Estancia Yerba Buena',
#   'obsDt': '2025-09-05 18:24',
#   'howMany': 1,
#   'lat': -29.5729946,
#   'lng': -71.299682,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271659708'},
#  {'speciesCode': 'dustap1',
#   'comName': 'Dusky Tapaculo',
#   'sciName': 'Scytalopus fuscus',
#   'locId': 'L5458420',
#   'locName': 'Estancia Yerba Buena',
#   'obsDt': '2025-09-05 18:24',
#   'howMany': 1,
#   'lat': -29.5729946,
#   'lng': -71.299682,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271659708'},
#  {'speciesCode': 'chitin1',
#   'comName': 'Chilean Tinamou',
#   'sciName': 'Nothoprocta perdicaria',
#   'locId': 'L5458420',
#   'locName': 'Estancia Yerba Buena',
#   'obsDt': '2025-09-05 18:24',
#   'howMany': 1,
#   'lat': -29.5729946,
#   'lng': -71.299682,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271659708'},
#  {'speciesCode': 'turvul',
#   'comName': 'Turkey Vulture',
#   'sciName': 'Cathartes aura',
#   'locId': 'L5458420',
#   'locName': 'Estancia Yerba Buena',
#   'obsDt': '2025-09-05 18:24',
#   'howMany': 1,
#   'lat': -29.5729946,
#   'lng': -71.299682,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271659708'},
#  {'speciesCode': 'rocpig',
#   'comName': 'Rock Pigeon',
#   'sciName': 'Columba livia',
#   'locId': 'L36198616',
#   'locName': 'Condominio Cuarto Centenario, Las Condes, Región Metropolitana, CL',
#   'obsDt': '2025-09-05 18:22',
#   'howMany': 1,
#   'lat': -33.4265073,
#   'lng': -70.5434377,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271661685',
#   'exoticCategory': 'N'},
#  {'speciesCode': 'rucspa1',
#   'comName': 'Rufous-collared Sparrow',
#   'sciName': 'Zonotrichia capensis',
#   'locId': 'L36198616',
#   'locName': 'Condominio Cuarto Centenario, Las Condes, Región Metropolitana, CL',
#   'obsDt': '2025-09-05 18:22',
#   'howMany': 2,
#   'lat': -33.4265073,
#   'lng': -70.5434377,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271661685'},
#  {'speciesCode': 'houwre4',
#   'comName': 'Southern House Wren',
#   'sciName': 'Troglodytes musculus',
#   'locId': 'L36198616',
#   'locName': 'Condominio Cuarto Centenario, Las Condes, Región Metropolitana, CL',
#   'obsDt': '2025-09-05 18:22',
#   'howMany': 2,
#   'lat': -33.4265073,
#   'lng': -70.5434377,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271661685'},
#  {'speciesCode': 'monpar',
#   'comName': 'Monk Parakeet',
#   'sciName': 'Myiopsitta monachus',
#   'locId': 'L36198616',
#   'locName': 'Condominio Cuarto Centenario, Las Condes, Región Metropolitana, CL',
#   'obsDt': '2025-09-05 18:22',
#   'howMany': 2,
#   'lat': -33.4265073,
#   'lng': -70.5434377,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271661685',
#   'exoticCategory': 'N'},
#  {'speciesCode': 'fiediu1',
#   'comName': 'Fire-eyed Diucon',
#   'sciName': 'Pyrope pyrope',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 1,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'calqua',
#   'comName': 'California Quail',
#   'sciName': 'Callipepla californica',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 5,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136',
#   'exoticCategory': 'N'},
#  {'speciesCode': 'ocftap1',
#   'comName': 'Ochre-flanked Tapaculo',
#   'sciName': 'Eugralla paradoxa',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 1,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'y00678',
#   'comName': 'Crested Caracara',
#   'sciName': 'Caracara plancus',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 3,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'soasni3',
#   'comName': 'Magellanic Snipe',
#   'sciName': 'Gallinago magellanica',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 3,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'shicow',
#   'comName': 'Shiny Cowbird',
#   'sciName': 'Molothrus bonariensis',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 1,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'blkvul',
#   'comName': 'Black Vulture',
#   'sciName': 'Coragyps atratus',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 9,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'sedwre',
#   'comName': 'Grass Wren',
#   'sciName': 'Cistothorus platensis',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 2,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'eardov1',
#   'comName': 'Eared Dove',
#   'sciName': 'Zenaida auriculata',
#   'locId': 'L50292471',
#   'locName': 'playa ancha alto',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 1,
#   'lat': -33.0501068,
#   'lng': -71.6507765,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271658220'},
#  {'speciesCode': 'chifli1',
#   'comName': 'Chilean Flicker',
#   'sciName': 'Colaptes pitius',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 1,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'brhgul2',
#   'comName': 'Brown-hooded Gull',
#   'sciName': 'Chroicocephalus maculipennis',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 1,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'magtap1',
#   'comName': 'Magellanic Tapaculo',
#   'sciName': 'Scytalopus magellanicus',
#   'locId': 'L976634',
#   'locName': 'Cabo Blanco',
#   'obsDt': '2025-09-05 18:17',
#   'howMany': 1,
#   'lat': -39.7884884,
#   'lng': -73.2486405,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271666136'},
#  {'speciesCode': 'codfin1',
#   'comName': 'Diuca Finch',
#   'sciName': 'Diuca diuca',
#   'locId': 'L12427719',
#   'locName': 'Avenida San Clemente, Puerto Varas, Los Lagos, CL (-41.326, -73.06)',
#   'obsDt': '2025-09-05 18:15',
#   'howMany': 3,
#   'lat': -41.326056,
#   'lng': -73.059533,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271660985'},
#  {'speciesCode': 'magwoo1',
#   'comName': 'Magellanic Woodpecker',
#   'sciName': 'Campephilus magellanicus',
#   'locId': 'L23496983',
#   'locName': 'Cabañas Los Faroles, Ensenada',
#   'obsDt': '2025-09-05 18:13',
#   'howMany': 3,
#   'lat': -41.2159811,
#   'lng': -72.5477179,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271669538'},
#  {'speciesCode': 'demwir1',
#   'comName': "Des Murs's Wiretail",
#   'sciName': 'Sylviorthorhynchus desmursii',
#   'locId': 'L23496983',
#   'locName': 'Cabañas Los Faroles, Ensenada',
#   'obsDt': '2025-09-05 18:13',
#   'howMany': 1,
#   'lat': -41.2159811,
#   'lng': -72.5477179,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271669538'},
#  {'speciesCode': 'pasfin1',
#   'comName': 'Patagonian Sierra Finch',
#   'sciName': 'Phrygilus patagonicus',
#   'locId': 'L23496983',
#   'locName': 'Cabañas Los Faroles, Ensenada',
#   'obsDt': '2025-09-05 18:13',
#   'howMany': 1,
#   'lat': -41.2159811,
#   'lng': -72.5477179,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271669538'},
#  {'speciesCode': 'sheowl',
#   'comName': 'Short-eared Owl',
#   'sciName': 'Asio flammeus',
#   'locId': 'L807764',
#   'locName': 'Las Quemas Altas',
#   'obsDt': '2025-09-05 17:59',
#   'howMany': 1,
#   'lat': -40.6284479,
#   'lng': -73.117919,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271661707'},
#  {'speciesCode': 'pattyr2',
#   'comName': 'Patagonian Tyrant',
#   'sciName': 'Colorhamphus parvirostris',
#   'locId': 'L807764',
#   'locName': 'Las Quemas Altas',
#   'obsDt': '2025-09-05 17:59',
#   'howMany': 1,
#   'lat': -40.6284479,
#   'lng': -73.117919,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271661707'},
#  {'speciesCode': 'pmtspi1',
#   'comName': 'Plain-mantled Tit-Spinetail',
#   'sciName': 'Leptasthenura aegithaloides',
#   'locId': 'L807764',
#   'locName': 'Las Quemas Altas',
#   'obsDt': '2025-09-05 17:59',
#   'howMany': 2,
#   'lat': -40.6284479,
#   'lng': -73.117919,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271661707'},
#  {'speciesCode': 'whtkit',
#   'comName': 'White-tailed Kite',
#   'sciName': 'Elanus leucurus',
#   'locId': 'L807764',
#   'locName': 'Las Quemas Altas',
#   'obsDt': '2025-09-05 17:59',
#   'howMany': 2,
#   'lat': -40.6284479,
#   'lng': -73.117919,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271661707'},
#  {'speciesCode': 'gryfin1',
#   'comName': 'Grassland Yellow-Finch',
#   'sciName': 'Sicalis luteola',
#   'locId': 'L807764',
#   'locName': 'Las Quemas Altas',
#   'obsDt': '2025-09-05 17:59',
#   'howMany': 3,
#   'lat': -40.6284479,
#   'lng': -73.117919,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271661707'},
#  {'speciesCode': 'strwoo6',
#   'comName': 'Striped Woodpecker',
#   'sciName': 'Dryobates lignarius',
#   'locId': 'L807764',
#   'locName': 'Las Quemas Altas',
#   'obsDt': '2025-09-05 17:59',
#   'howMany': 1,
#   'lat': -40.6284479,
#   'lng': -73.117919,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271661707'},
#  {'speciesCode': 'rutpla1',
#   'comName': 'Rufous-tailed Plantcutter',
#   'sciName': 'Phytotoma rara',
#   'locId': 'L9791779',
#   'locName': 'Plaza Zañartu',
#   'obsDt': '2025-09-05 17:58',
#   'howMany': 1,
#   'lat': -33.472627,
#   'lng': -70.6058755,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271657931'},
#  {'speciesCode': 'chimoc1',
#   'comName': 'Chilean Mockingbird',
#   'sciName': 'Mimus thenca',
#   'locId': 'L52474915',
#   'locName': 'Trip to Cabo Blanco 1',
#   'obsDt': '2025-09-05 17:50',
#   'howMany': 2,
#   'lat': -39.828797,
#   'lng': -73.242242,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271657790'},
#  {'speciesCode': 'whtgre3',
#   'comName': 'White-tufted Grebe',
#   'sciName': 'Rollandia rolland',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 1,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'uplgoo1',
#   'comName': 'Upland Goose',
#   'sciName': 'Chloephaga picta',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 4,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'chiwig1',
#   'comName': 'Chiloe Wigeon',
#   'sciName': 'Mareca sibilatrix',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 2,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'magoys1',
#   'comName': 'Magellanic Oystercatcher',
#   'sciName': 'Haematopus leucopodus',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 2,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'souful1',
#   'comName': 'Southern Fulmar',
#   'sciName': 'Fulmarus glacialoides',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 1,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'dolgul2',
#   'comName': 'Dolphin Gull',
#   'sciName': 'Leucophaeus scoresbii',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 2,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'blnswa2',
#   'comName': 'Black-necked Swan',
#   'sciName': 'Cygnus melancoryphus',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 2,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'angpet1',
#   'comName': 'Southern Giant-Petrel',
#   'sciName': 'Macronectes giganteus',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 1,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'impcor1',
#   'comName': 'Imperial Cormorant',
#   'sciName': 'Leucocarbo atriceps',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 12,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'creduc1',
#   'comName': 'Crested Duck',
#   'sciName': 'Lophonetta specularioides',
#   'locId': 'L35274711',
#   'locName': 'Puerto Natales--Muelle histórico',
#   'obsDt': '2025-09-05 17:49',
#   'howMany': 1,
#   'lat': -51.7234298,
#   'lng': -72.5102142,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271648440'},
#  {'speciesCode': 'amekes',
#   'comName': 'American Kestrel',
#   'sciName': 'Falco sparverius',
#   'locId': 'L52474223',
#   'locName': 'Carahue, Araucanía, CL (-38,715, -73,429)',
#   'obsDt': '2025-09-05 17:48',
#   'howMany': 1,
#   'lat': -38.7152212,
#   'lng': -73.4291277,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271654655'},
#  {'speciesCode': 'flistd1',
#   'comName': 'Flightless Steamer-Duck',
#   'sciName': 'Tachyeres pteneres',
#   'locId': 'L52474172',
#   'locName': 'CL (-42.065, -72.479)',
#   'obsDt': '2025-09-05 17:46',
#   'howMany': 2,
#   'lat': -42.0653,
#   'lng': -72.4789083,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271654420'},
#  {'speciesCode': 'neocor',
#   'comName': 'Neotropic Cormorant',
#   'sciName': 'Nannopterum brasilianum',
#   'locId': 'L9302170',
#   'locName': 'Villa Parque Austral, Osorno, Región de los Lagos, CL (-40.586, -73.113)',
#   'obsDt': '2025-09-05 17:42',
#   'howMany': 1,
#   'lat': -40.5858874,
#   'lng': -73.1131691,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271662567'},
#  {'speciesCode': 'slbpar1',
#   'comName': 'Slender-billed Parakeet',
#   'sciName': 'Enicognathus leptorhynchus',
#   'locId': 'L9302170',
#   'locName': 'Villa Parque Austral, Osorno, Región de los Lagos, CL (-40.586, -73.113)',
#   'obsDt': '2025-09-05 17:42',
#   'howMany': 67,
#   'lat': -40.5858874,
#   'lng': -73.1131691,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271662567'},
#  {'speciesCode': 'ausbla1',
#   'comName': 'Austral Blackbird',
#   'sciName': 'Curaeus curaeus',
#   'locId': 'L44466843',
#   'locName': 'Chahuilco',
#   'obsDt': '2025-09-05 17:39',
#   'lat': -40.7199583,
#   'lng': -73.2343483,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271655199'},
#  {'speciesCode': 'auspar1',
#   'comName': 'Austral Parakeet',
#   'sciName': 'Enicognathus ferrugineus',
#   'locId': 'L44466843',
#   'locName': 'Chahuilco',
#   'obsDt': '2025-09-05 17:39',
#   'lat': -40.7199583,
#   'lng': -73.2343483,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271655199'},
#  {'speciesCode': 'aupowl1',
#   'comName': 'Austral Pygmy-Owl',
#   'sciName': 'Glaucidium nana',
#   'locId': 'L44466843',
#   'locName': 'Chahuilco',
#   'obsDt': '2025-09-05 17:39',
#   'lat': -40.7199583,
#   'lng': -73.2343483,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271655199'},
#  {'speciesCode': 'rulowl1',
#   'comName': 'Rufous-legged Owl',
#   'sciName': 'Strix rufipes',
#   'locId': 'L44466843',
#   'locName': 'Chahuilco',
#   'obsDt': '2025-09-05 17:39',
#   'lat': -40.7199583,
#   'lng': -73.2343483,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271655199'},
#  {'speciesCode': 'redsho1',
#   'comName': 'Red Shoveler',
#   'sciName': 'Spatula platalea',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2025-09-05 17:38',
#   'howMany': 2,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271657918'},
#  {'speciesCode': 'ashgoo1',
#   'comName': 'Ashy-headed Goose',
#   'sciName': 'Chloephaga poliocephala',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2025-09-05 17:38',
#   'howMany': 2,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271657918'},
#  {'speciesCode': 'chifla1',
#   'comName': 'Chilean Flamingo',
#   'sciName': 'Phoenicopterus chilensis',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2025-09-05 17:38',
#   'howMany': 3,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271657918'},
#  {'speciesCode': 'regcoo1',
#   'comName': 'Red-gartered Coot',
#   'sciName': 'Fulica armillata',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2025-09-05 17:38',
#   'howMany': 16,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271657918'},
#  {'speciesCode': 'cintea',
#   'comName': 'Cinnamon Teal',
#   'sciName': 'Spatula cyanoptera',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2025-09-05 17:38',
#   'howMany': 2,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271657918'},
#  {'speciesCode': 'flystd1',
#   'comName': 'Flying Steamer-Duck',
#   'sciName': 'Tachyeres patachonicus',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2025-09-05 17:38',
#   'howMany': 2,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271657918'},
#  {'speciesCode': 'rucdot1',
#   'comName': 'Rufous-chested Dotterel',
#   'sciName': 'Zonibyx modestus',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 17,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'greyel',
#   'comName': 'Greater Yellowlegs',
#   'sciName': 'Tringa melanoleuca',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 3,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'whfibi',
#   'comName': 'White-faced Ibis',
#   'sciName': 'Plegadis chihi',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 1,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'hudgod',
#   'comName': 'Hudsonian Godwit',
#   'sciName': 'Limosa haemastica',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 2,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'buwcin1',
#   'comName': 'Buff-winged Cinclodes',
#   'sciName': 'Cinclodes fuscus',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 1,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'baisan',
#   'comName': "Baird's Sandpiper",
#   'sciName': 'Calidris bairdii',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 18,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'colplo1',
#   'comName': 'Collared Plover',
#   'sciName': 'Anarhynchus collaris',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 1,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'whcpin',
#   'comName': 'White-cheeked Pintail',
#   'sciName': 'Anas bahamensis',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 9,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'willet1',
#   'comName': 'Willet',
#   'sciName': 'Tringa semipalmata',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 1,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'lesyel',
#   'comName': 'Lesser Yellowlegs',
#   'sciName': 'Tringa flavipes',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 37,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'snoegr',
#   'comName': 'Snowy Egret',
#   'sciName': 'Egretta thula',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 7,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'bknsti',
#   'comName': 'Black-necked Stilt',
#   'sciName': 'Himantopus mexicanus',
#   'locId': 'L629582',
#   'locName': 'Rocuant--Canal El Morro',
#   'obsDt': '2025-09-05 17:33',
#   'howMany': 28,
#   'lat': -36.7354449,
#   'lng': -73.0929422,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664966'},
#  {'speciesCode': 'chutap1',
#   'comName': 'Chucao Tapaculo',
#   'sciName': 'Scelorchilus rubecula',
#   'locId': 'L3333239',
#   'locName': 'Río Cochamó--desembocadura',
#   'obsDt': '2025-09-05 17:16',
#   'howMany': 1,
#   'lat': -41.4986782,
#   'lng': -72.2676373,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271651846'},
#  {'speciesCode': 'rinkin1',
#   'comName': 'Ringed Kingfisher',
#   'sciName': 'Megaceryle torquata',
#   'locId': 'L3333239',
#   'locName': 'Río Cochamó--desembocadura',
#   'obsDt': '2025-09-05 17:16',
#   'howMany': 2,
#   'lat': -41.4986782,
#   'lng': -72.2676373,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271651846'},
#  {'speciesCode': 'corpip1',
#   'comName': 'Correndera Pipit',
#   'sciName': 'Anthus correndera',
#   'locId': 'L22420601',
#   'locName': 'Complejo Humedal Rocuant-Andalién--Aeropuerto',
#   'obsDt': '2025-09-05 17:16',
#   'howMany': 1,
#   'lat': -36.7522689,
#   'lng': -73.0652064,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664120'},
#  {'speciesCode': 'cosswa1',
#   'comName': 'Coscoroba Swan',
#   'sciName': 'Coscoroba coscoroba',
#   'locId': 'L22420601',
#   'locName': 'Complejo Humedal Rocuant-Andalién--Aeropuerto',
#   'obsDt': '2025-09-05 17:16',
#   'howMany': 37,
#   'lat': -36.7522689,
#   'lng': -73.0652064,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664120'},
#  {'speciesCode': 'ausneg1',
#   'comName': 'Austral Negrito',
#   'sciName': 'Lessonia rufa',
#   'locId': 'L22420601',
#   'locName': 'Complejo Humedal Rocuant-Andalién--Aeropuerto',
#   'obsDt': '2025-09-05 17:16',
#   'howMany': 2,
#   'lat': -36.7522689,
#   'lng': -73.0652064,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664120'},
#  {'speciesCode': 'bthhue1',
#   'comName': 'Black-throated Huet-huet',
#   'sciName': 'Pteroptochos tarnii',
#   'locId': 'L38449561',
#   'locName': '5520594, Puerto Montt CL-Región de Los Lagos -41.37027, -72.72290',
#   'obsDt': '2025-09-05 16:59',
#   'howMany': 1,
#   'lat': -41.370271,
#   'lng': -72.722904,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271650889'},
#  {'speciesCode': 'pigdov1',
#   'comName': 'Picui Ground Dove',
#   'sciName': 'Columbina picui',
#   'locId': 'L512176',
#   'locName': 'Pichilemu--Laguna Petrel (Humedal Urbano)',
#   'obsDt': '2025-09-05 16:55',
#   'howMany': 2,
#   'lat': -34.3824693,
#   'lng': -71.9981289,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664420'},
#  {'speciesCode': 'mcrtyr1',
#   'comName': 'Many-colored Rush Tyrant',
#   'sciName': 'Tachuris rubrigastra',
#   'locId': 'L512176',
#   'locName': 'Pichilemu--Laguna Petrel (Humedal Urbano)',
#   'obsDt': '2025-09-05 16:55',
#   'howMany': 5,
#   'lat': -34.3824693,
#   'lng': -71.9981289,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664420'},
#  {'speciesCode': 'gregre1',
#   'comName': 'Great Grebe',
#   'sciName': 'Podiceps major',
#   'locId': 'L512176',
#   'locName': 'Pichilemu--Laguna Petrel (Humedal Urbano)',
#   'obsDt': '2025-09-05 16:55',
#   'howMany': 2,
#   'lat': -34.3824693,
#   'lng': -71.9981289,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664420'},
#  {'speciesCode': 'ameoys',
#   'comName': 'American Oystercatcher',
#   'sciName': 'Haematopus palliatus',
#   'locId': 'L512176',
#   'locName': 'Pichilemu--Laguna Petrel (Humedal Urbano)',
#   'obsDt': '2025-09-05 16:55',
#   'howMany': 2,
#   'lat': -34.3824693,
#   'lng': -71.9981289,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664420'},
#  {'speciesCode': 'dutcan1',
#   'comName': 'Dusky-tailed Canastero',
#   'sciName': 'Pseudasthenes humicola',
#   'locId': 'L512176',
#   'locName': 'Pichilemu--Laguna Petrel (Humedal Urbano)',
#   'obsDt': '2025-09-05 16:55',
#   'howMany': 1,
#   'lat': -34.3824693,
#   'lng': -71.9981289,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664420'},
#  {'speciesCode': 'silgre1',
#   'comName': 'Silvery Grebe',
#   'sciName': 'Podiceps occipitalis',
#   'locId': 'L512176',
#   'locName': 'Pichilemu--Laguna Petrel (Humedal Urbano)',
#   'obsDt': '2025-09-05 16:55',
#   'howMany': 6,
#   'lat': -34.3824693,
#   'lng': -71.9981289,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664420'},
#  {'speciesCode': 'lakduc1',
#   'comName': 'Lake Duck',
#   'sciName': 'Oxyura vittata',
#   'locId': 'L512176',
#   'locName': 'Pichilemu--Laguna Petrel (Humedal Urbano)',
#   'obsDt': '2025-09-05 16:55',
#   'howMany': 3,
#   'lat': -34.3824693,
#   'lng': -71.9981289,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664420'},
#  {'speciesCode': 'whwcoo1',
#   'comName': 'White-winged Coot',
#   'sciName': 'Fulica leucoptera',
#   'locId': 'L512176',
#   'locName': 'Pichilemu--Laguna Petrel (Humedal Urbano)',
#   'obsDt': '2025-09-05 16:55',
#   'howMany': 13,
#   'lat': -34.3824693,
#   'lng': -71.9981289,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664420'},
#  {'speciesCode': 'perpel1',
#   'comName': 'Peruvian Pelican',
#   'sciName': 'Pelecanus thagus',
#   'locId': 'L947356',
#   'locName': 'Moncul',
#   'obsDt': '2025-09-05 16:53',
#   'howMany': 2,
#   'lat': -38.7467871,
#   'lng': -73.4363937,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271652291'},
#  {'speciesCode': 'soater1',
#   'comName': 'South American Tern',
#   'sciName': 'Sterna hirundinacea',
#   'locId': 'L947356',
#   'locName': 'Moncul',
#   'obsDt': '2025-09-05 16:53',
#   'howMany': 2,
#   'lat': -38.7467871,
#   'lng': -73.4363937,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271652291'},
#  {'speciesCode': 'truter',
#   'comName': 'Snowy-crowned Tern',
#   'sciName': 'Sterna trudeaui',
#   'locId': 'L947356',
#   'locName': 'Moncul',
#   'obsDt': '2025-09-05 16:53',
#   'howMany': 1,
#   'lat': -38.7467871,
#   'lng': -73.4363937,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271652291'},
#  {'speciesCode': 'yewbla2',
#   'comName': 'Yellow-winged Blackbird',
#   'sciName': 'Agelasticus thilius',
#   'locId': 'L20473017',
#   'locName': 'Universidad de Concepción--Campus Chillán',
#   'obsDt': '2025-09-05 16:44',
#   'howMany': 1,
#   'lat': -36.595976,
#   'lng': -72.0841944,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271663447'},
#  {'speciesCode': 'wepdov1',
#   'comName': 'West Peruvian Dove',
#   'sciName': 'Zenaida meloda',
#   'locId': 'L31381629',
#   'locName': '0885 Pedro Correa, Penaflor, Región Metropolitana, CL (-33.62, -70.89)',
#   'obsDt': '2025-09-05 16:43',
#   'howMany': 1,
#   'lat': -33.6195381,
#   'lng': -70.8896039,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271661811'},
#  {'speciesCode': 'cinhar1',
#   'comName': 'Cinereous Harrier',
#   'sciName': 'Circus cinereus',
#   'locId': 'L6968952',
#   'locName': 'Pampa Jardín Oriente',
#   'obsDt': '2025-09-05 16:42',
#   'howMany': 1,
#   'lat': -41.438494,
#   'lng': -72.922582,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271664186'},
#  {'speciesCode': 'dafgrt1',
#   'comName': 'Dark-faced Ground-Tyrant',
#   'sciName': 'Muscisaxicola maclovianus',
#   'locId': 'L52472261',
#   'locName': 'Mirador Rocas De Tabulanque',
#   'obsDt': '2025-09-05 16:26',
#   'howMany': 1,
#   'lat': -33.4141181,
#   'lng': -71.7017384,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271645474'},
#  {'speciesCode': 'crgdov1',
#   'comName': 'Croaking Ground Dove',
#   'sciName': 'Columbina cruziana',
#   'locId': 'L52471235',
#   'locName': '35 C-35, Tierra Amarilla, Atacama, CL (-27.948, -70)',
#   'obsDt': '2025-09-05 15:41',
#   'howMany': 1,
#   'lat': -27.9476994,
#   'lng': -70.0004607,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271640916'},
#  {'speciesCode': 'oashum1',
#   'comName': 'Oasis Hummingbird',
#   'sciName': 'Rhodopis vesper',
#   'locId': 'L52471235',
#   'locName': '35 C-35, Tierra Amarilla, Atacama, CL (-27.948, -70)',
#   'obsDt': '2025-09-05 15:41',
#   'howMany': 1,
#   'lat': -27.9476994,
#   'lng': -70.0004607,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271640916'},
#  {'speciesCode': 'siltea1',
#   'comName': 'Silver Teal',
#   'sciName': 'Spatula versicolor',
#   'locId': 'L52469462',
#   'locName': 'Ruta 9 Norte, Laguna Blanca CL-Magallanes and Antartica Chilena Region -52.16013, -71.36281',
#   'obsDt': '2025-09-05 15:38',
#   'howMany': 1,
#   'lat': -52.160126,
#   'lng': -71.362814,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271632880'},
#  {'speciesCode': 'surfbi',
#   'comName': 'Surfbird',
#   'sciName': 'Calidris virgata',
#   'locId': 'L13531442',
#   'locName': 'Tabulanque',
#   'obsDt': '2025-09-05 15:28',
#   'howMany': 1,
#   'lat': -33.4163991,
#   'lng': -71.702241,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271643679'},
#  {'speciesCode': 'rudtur',
#   'comName': 'Ruddy Turnstone',
#   'sciName': 'Arenaria interpres',
#   'locId': 'L13531442',
#   'locName': 'Tabulanque',
#   'obsDt': '2025-09-05 15:28',
#   'howMany': 18,
#   'lat': -33.4163991,
#   'lng': -71.702241,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271643679'},
#  {'speciesCode': 'bawswa1',
#   'comName': 'Blue-and-white Swallow',
#   'sciName': 'Pygochelidon cyanoleuca',
#   'locId': 'L13531442',
#   'locName': 'Tabulanque',
#   'obsDt': '2025-09-05 15:28',
#   'howMany': 3,
#   'lat': -33.4163991,
#   'lng': -71.702241,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271643679'},
#  {'speciesCode': 'aplfal',
#   'comName': 'Aplomado Falcon',
#   'sciName': 'Falco femoralis',
#   'locId': 'L52470527',
#   'locName': 'Ruta 5 Norte, Ovalle CL-Región de Coquimbo -30.48658, -71.47770',
#   'obsDt': '2025-09-05 15:27',
#   'howMany': 1,
#   'lat': -30.486578,
#   'lng': -71.477704,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271637663'},
#  {'speciesCode': 'mosfin1',
#   'comName': 'Mourning Sierra Finch',
#   'sciName': 'Rhopospina fruticeti',
#   'locId': 'L34026129',
#   'locName': 'Quinchos Cerro Renca',
#   'obsDt': '2025-09-05 15:22',
#   'howMany': 6,
#   'lat': -33.3975402,
#   'lng': -70.7194357,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271638949'},
#  {'speciesCode': 'andcon1',
#   'comName': 'Andean Condor',
#   'sciName': 'Vultur gryphus',
#   'locId': 'L34026129',
#   'locName': 'Quinchos Cerro Renca',
#   'obsDt': '2025-09-05 15:22',
#   'howMany': 1,
#   'lat': -33.3975402,
#   'lng': -70.7194357,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271638949'},
#  {'speciesCode': 'kelgoo1',
#   'comName': 'Kelp Goose',
#   'sciName': 'Chloephaga hybrida',
#   'locId': 'L1033522',
#   'locName': 'Fuerte Bulnes',
#   'obsDt': '2025-09-05 15:06',
#   'howMany': 3,
#   'lat': -53.6303509,
#   'lng': -70.9171343,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271643435'},
#  {'speciesCode': 'madpet1',
#   'comName': 'Magellanic Diving-Petrel',
#   'sciName': 'Pelecanoides magellani',
#   'locId': 'L1033522',
#   'locName': 'Fuerte Bulnes',
#   'obsDt': '2025-09-05 15:06',
#   'howMany': 1,
#   'lat': -53.6303509,
#   'lng': -70.9171343,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271643435'},
#  {'speciesCode': 'blaoys1',
#   'comName': 'Blackish Oystercatcher',
#   'sciName': 'Haematopus ater',
#   'locId': 'L1033522',
#   'locName': 'Fuerte Bulnes',
#   'obsDt': '2025-09-05 15:06',
#   'howMany': 1,
#   'lat': -53.6303509,
#   'lng': -70.9171343,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271643435'},
#  {'speciesCode': 'magpen1',
#   'comName': 'Magellanic Penguin',
#   'sciName': 'Spheniscus magellanicus',
#   'locId': 'L1033522',
#   'locName': 'Fuerte Bulnes',
#   'obsDt': '2025-09-05 15:06',
#   'howMany': 4,
#   'lat': -53.6303509,
#   'lng': -70.9171343,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271643435'},
#  {'speciesCode': 'bkbalb',
#   'comName': 'Black-browed Albatross',
#   'sciName': 'Thalassarche melanophris',
#   'locId': 'L1033522',
#   'locName': 'Fuerte Bulnes',
#   'obsDt': '2025-09-05 15:06',
#   'howMany': 2,
#   'lat': -53.6303509,
#   'lng': -70.9171343,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271643435'},
#  {'speciesCode': 'slccoo1',
#   'comName': 'Slate-colored Coot',
#   'sciName': 'Fulica ardesiaca',
#   'locId': 'L668852',
#   'locName': 'Río Lluta--Desembocadura',
#   'obsDt': '2025-09-05 15:04',
#   'howMany': 2,
#   'lat': -18.4165392,
#   'lng': -70.3224081,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271653553'},
#  {'speciesCode': 'semplo',
#   'comName': 'Semipalmated Plover',
#   'sciName': 'Charadrius semipalmatus',
#   'locId': 'L668852',
#   'locName': 'Río Lluta--Desembocadura',
#   'obsDt': '2025-09-05 15:04',
#   'howMany': 4,
#   'lat': -18.4165392,
#   'lng': -70.3224081,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271653553'},
#  {'speciesCode': 'comgal1',
#   'comName': 'Common Gallinule',
#   'sciName': 'Gallinula galeata',
#   'locId': 'L668852',
#   'locName': 'Río Lluta--Desembocadura',
#   'obsDt': '2025-09-05 15:04',
#   'howMany': 20,
#   'lat': -18.4165392,
#   'lng': -70.3224081,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271653553'},
#  {'speciesCode': 'cincon1',
#   'comName': 'Cinereous Conebill',
#   'sciName': 'Conirostrum cinereum',
#   'locId': 'L668852',
#   'locName': 'Río Lluta--Desembocadura',
#   'obsDt': '2025-09-05 15:04',
#   'howMany': 4,
#   'lat': -18.4165392,
#   'lng': -70.3224081,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271653553'},
#  {'speciesCode': 'grygul',
#   'comName': 'Gray Gull',
#   'sciName': 'Leucophaeus modestus',
#   'locId': 'L668852',
#   'locName': 'Río Lluta--Desembocadura',
#   'obsDt': '2025-09-05 15:04',
#   'howMany': 20,
#   'lat': -18.4165392,
#   'lng': -70.3224081,
# ...
#   'locName': 'PN Lauca--Parinacota',
#   'obsDt': '2025-08-31 10:30',
#   'howMany': 2,
#   'lat': -18.2026148,
#   'lng': -69.2682409,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271192471'},
#  {'speciesCode': 'maspet',
#   'comName': "Markham's Storm-Petrel",
#   'sciName': 'Hydrobates markhami',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 6,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'blkter',
#   'comName': 'Black Tern',
#   'sciName': 'Chlidonias niger',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 1,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'maspet3',
#   'comName': 'Masatierra Petrel',
#   'sciName': 'Pterodroma defilippiana',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 25,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'salalb1',
#   'comName': "Salvin's Albatross",
#   'sciName': 'Thalassarche salvini',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 1,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'royalb3',
#   'comName': 'Northern Royal Albatross',
#   'sciName': 'Diomedea sanfordi',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 2,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'pedpet1',
#   'comName': 'Peruvian Diving-Petrel',
#   'sciName': 'Pelecanoides garnotii',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 10,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'rispet1',
#   'comName': 'Ringed Storm-Petrel',
#   'sciName': 'Hydrobates hornbyi',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 20,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'wvspet1',
#   'comName': "Elliot's Storm-Petrel",
#   'sciName': 'Oceanites gracilis',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 25,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'cappet',
#   'comName': 'Pintado Petrel',
#   'sciName': 'Daption capense',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 1,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'whcpet1',
#   'comName': 'White-chinned Petrel',
#   'sciName': 'Procellaria aequinoctialis',
#   'locId': 'L16351579',
#   'locName': 'Antofagasta--Pelágico',
#   'obsDt': '2025-08-31 08:30',
#   'howMany': 9,
#   'lat': -23.6863002,
#   'lng': -70.8154632,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270744849'},
#  {'speciesCode': 'whthaw1',
#   'comName': 'White-throated Hawk',
#   'sciName': 'Buteo albigula',
#   'locId': 'L7676901',
#   'locName': 'Estero Coliumo--Desembocadura',
#   'obsDt': '2025-08-30 16:53',
#   'howMany': 1,
#   'lat': -36.5578172,
#   'lng': -72.9542184,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S270477286'},
#  {'speciesCode': 'snoplo5',
#   'comName': 'Snowy Plover',
#   'sciName': 'Anarhynchus nivosus',
#   'locId': 'L509064',
#   'locName': 'SN Laguna Conchalí',
#   'obsDt': '2025-08-30 15:51',
#   'howMany': 1,
#   'lat': -31.8780678,
#   'lng': -71.4966631,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271438882'},
#  {'speciesCode': 'andlap1',
#   'comName': 'Andean Lapwing',
#   'sciName': 'Vanellus resplendens',
#   'locId': 'L10697100',
#   'locName': 'PN Lauca--Lago Chungará sur',
#   'obsDt': '2025-08-30 15:19',
#   'howMany': 1,
#   'lat': -18.2835621,
#   'lng': -69.1343836,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S271012354'},
#  {'speciesCode': 'stbear2',
#   'comName': 'Straight-billed Earthcreeper',
#   'sciName': 'Ochetorhynchus ruficaudus',
#   'locId': 'L52206628',
#   'locName': 'Campamento Lázaro',
#   'obsDt': '2025-08-30 09:20',
#   'howMany': 1,
#   'lat': -26.865861,
#   'lng': -69.3585812,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270375694'},
#  {'speciesCode': 'bulalb2',
#   'comName': "Buller's Albatross",
#   'sciName': 'Thalassarche bulleri',
#   'locId': 'L52218080',
#   'locName': 'Auto selected -32.72471, -71.59497',
#   'obsDt': '2025-08-30 08:36',
#   'howMany': 1,
#   'lat': -32.724709,
#   'lng': -71.594974,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270424131'},
#  {'speciesCode': 'wespet1',
#   'comName': 'Westland Petrel',
#   'sciName': 'Procellaria westlandica',
#   'locId': 'L52218080',
#   'locName': 'Auto selected -32.72471, -71.59497',
#   'obsDt': '2025-08-30 08:36',
#   'howMany': 2,
#   'lat': -32.724709,
#   'lng': -71.594974,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270424131'},
#  {'speciesCode': 'chisku1',
#   'comName': 'Chilean Skua',
#   'sciName': 'Stercorarius chilensis',
#   'locId': 'L52218080',
#   'locName': 'Auto selected -32.72471, -71.59497',
#   'obsDt': '2025-08-30 08:36',
#   'howMany': 1,
#   'lat': -32.724709,
#   'lng': -71.594974,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270424131'},
#  {'speciesCode': 'wispet',
#   'comName': "Wilson's Storm-Petrel",
#   'sciName': 'Oceanites oceanicus',
#   'locId': 'L52218080',
#   'locName': 'Auto selected -32.72471, -71.59497',
#   'obsDt': '2025-08-30 08:36',
#   'howMany': 18,
#   'lat': -32.724709,
#   'lng': -71.594974,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270424131'},
#  {'speciesCode': 'antalb1',
#   'comName': 'Antipodean Albatross',
#   'sciName': 'Diomedea antipodensis',
#   'locId': 'L52218080',
#   'locName': 'Auto selected -32.72471, -71.59497',
#   'obsDt': '2025-08-30 08:36',
#   'howMany': 1,
#   'lat': -32.724709,
#   'lng': -71.594974,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': True,
#   'subId': 'S270424131'},
#  {'speciesCode': 'pifshe',
#   'comName': 'Pink-footed Shearwater',
#   'sciName': 'Ardenna creatopus',
#   'locId': 'L52218080',
#   'locName': 'Auto selected -32.72471, -71.59497',
#   'obsDt': '2025-08-30 08:36',
#   'howMany': 2,
#   'lat': -32.724709,
#   'lng': -71.594974,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270424131'},
#  {'speciesCode': 'norgip1',
#   'comName': 'Northern Giant-Petrel',
#   'sciName': 'Macronectes halli',
#   'locId': 'L570174',
#   'locName': 'Quintero--Pelágico',
#   'obsDt': '2025-08-30 08:04',
#   'howMany': 2,
#   'lat': -32.7693779,
#   'lng': -71.5838242,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270407086'},
#  {'speciesCode': 'wbctyr1',
#   'comName': 'White-browed Chat-Tyrant',
#   'sciName': 'Ochthoeca leucophrys',
#   'locId': 'L12740775',
#   'locName': 'Putre--APTHAPI',
#   'obsDt': '2025-08-29 15:19',
#   'howMany': 2,
#   'lat': -18.1944401,
#   'lng': -69.5513924,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270830088'},
#  {'speciesCode': 'scrcow1',
#   'comName': 'Screaming Cowbird',
#   'sciName': 'Molothrus rufoaxillaris',
#   'locId': 'L31381629',
#   'locName': '0885 Pedro Correa, Penaflor, Región Metropolitana, CL (-33.62, -70.89)',
#   'obsDt': '2025-08-29 10:38',
#   'howMany': 3,
#   'lat': -33.6195381,
#   'lng': -70.8896039,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': True,
#   'subId': 'S270195724'},
#  {'speciesCode': 'andtin1',
#   'comName': 'Andean Tinamou',
#   'sciName': 'Nothoprocta pentlandii',
#   'locId': 'L40010430',
#   'locName': 'A-213, Socoroma Cultivos Norte',
#   'obsDt': '2025-08-29 07:51',
#   'howMany': 2,
#   'lat': -18.2665773,
#   'lng': -69.5946684,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': True,
#   'subId': 'S270215903'},
#  {'speciesCode': 'spvear1',
#   'comName': 'Sparkling Violetear',
#   'sciName': 'Colibri coruscans',
#   'locId': 'L40010430',
#   'locName': 'A-213, Socoroma Cultivos Norte',
#   'obsDt': '2025-08-29 07:51',
#   'howMany': 1,
#   'lat': -18.2665773,
#   'lng': -69.5946684,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270215903'},
#  {'speciesCode': 'diaplo1',
#   'comName': 'Diademed Sandpiper-Plover',
#   'sciName': 'Phegornis mitchellii',
#   'locId': 'L52442270',
#   'locName': 'Antofagasta, Antofagasta, CL (-24.365, -68.634)',
#   'obsDt': '2025-08-29 07:48',
#   'howMany': 2,
#   'lat': -24.3650397,
#   'lng': -68.6344132,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271504376'},
#  {'speciesCode': 'crrmin1',
#   'comName': 'Creamy-rumped Miner',
#   'sciName': 'Geositta isabellina',
#   'locId': 'L52442270',
#   'locName': 'Antofagasta, Antofagasta, CL (-24.365, -68.634)',
#   'obsDt': '2025-08-29 07:48',
#   'howMany': 2,
#   'lat': -24.3650397,
#   'lng': -68.6344132,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271504376'},
#  {'speciesCode': 'chtsee1',
#   'comName': 'Chestnut-throated Seedeater',
#   'sciName': 'Sporophila telasco',
#   'locId': 'L719036',
#   'locName': 'Valle de Azapa--Santuario del Picaflor',
#   'obsDt': '2025-08-28 16:17',
#   'howMany': 2,
#   'lat': -18.5318936,
#   'lng': -70.1666683,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270064008'},
#  {'speciesCode': 'gybsee1',
#   'comName': 'Gray-breasted Seedsnipe',
#   'sciName': 'Thinocorus orbignyianus',
#   'locId': 'L13196642',
#   'locName': 'Ea. Laguna Amarga',
#   'obsDt': '2025-08-28 09:49',
#   'howMany': 1,
#   'lat': -50.9742839,
#   'lng': -72.7823128,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S270042386'},
#  {'speciesCode': 'punsni1',
#   'comName': 'Puna Snipe',
#   'sciName': 'Gallinago andina',
#   'locId': 'L52442270',
#   'locName': 'Antofagasta, Antofagasta, CL (-24.365, -68.634)',
#   'obsDt': '2025-08-28 09:28',
#   'howMany': 1,
#   'lat': -24.3650397,
#   'lng': -68.6344132,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271503537'},
#  {'speciesCode': 'pepowl1',
#   'comName': 'Peruvian Pygmy-Owl',
#   'sciName': 'Glaucidium peruanum',
#   'locId': 'L44037803',
#   'locName': 'Camarones, Arica y Parinacota',
#   'obsDt': '2025-08-28 08:52',
#   'howMany': 1,
#   'lat': -19.0070068,
#   'lng': -69.875016,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270851416'},
#  {'speciesCode': 'brcfly3',
#   'comName': 'Rufescent Flycatcher',
#   'sciName': 'Myiophobus rufescens',
#   'locId': 'L44037803',
#   'locName': 'Camarones, Arica y Parinacota',
#   'obsDt': '2025-08-28 08:52',
#   'howMany': 1,
#   'lat': -19.0070068,
#   'lng': -69.875016,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270851416'},
#  {'speciesCode': 'andswi1',
#   'comName': 'Andean Swift',
#   'sciName': 'Aeronautes andecolus',
#   'locId': 'L44037803',
#   'locName': 'Camarones, Arica y Parinacota',
#   'obsDt': '2025-08-28 08:52',
#   'howMany': 1,
#   'lat': -19.0070068,
#   'lng': -69.875016,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S270851416'},
#  {'speciesCode': 'musduc',
#   'comName': 'Muscovy Duck',
#   'sciName': 'Cairina moschata',
#   'locId': 'L3679772',
#   'locName': 'Canal Ifarle',
#   'obsDt': '2025-08-26 16:50',
#   'howMany': 1,
#   'lat': -36.7461661,
#   'lng': -73.0837101,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S269757739',
#   'exoticCategory': 'X'},
#  {'speciesCode': 'yersis1',
#   'comName': 'Yellow-rumped Siskin',
#   'sciName': 'Spinus uropygialis',
#   'locId': 'L52442238',
#   'locName': 'Antofagasta, Antofagasta, CL (-24.368, -68.628)',
#   'obsDt': '2025-08-26 15:40',
#   'howMany': 2,
#   'lat': -24.368035,
#   'lng': -68.6284417,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S271502974'},
#  {'speciesCode': 'horcoo1',
#   'comName': 'Horned Coot',
#   'sciName': 'Fulica cornuta',
#   'locId': 'L2961343',
#   'locName': 'RN Los Flamencos--Lagunas Miscanti y Miñiques [usar hotspots específicos]',
#   'obsDt': '2025-08-26 10:30',
#   'howMany': 85,
#   'lat': -23.7542139,
#   'lng': -67.7863312,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S269750404'},
#  {'speciesCode': 'puntin1',
#   'comName': 'Puna Tinamou',
#   'sciName': 'Tinamotis pentlandii',
#   'locId': 'L2961343',
#   'locName': 'RN Los Flamencos--Lagunas Miscanti y Miñiques [usar hotspots específicos]',
#   'obsDt': '2025-08-26 10:30',
#   'howMany': 3,
#   'lat': -23.7542139,
#   'lng': -67.7863312,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S269750404'},
#  {'speciesCode': 'shbcan2',
#   'comName': 'Sharp-billed Canastero',
#   'sciName': 'Asthenes pyrrholeuca',
#   'locId': 'L5842556',
#   'locName': 'RN Río de Los Cipreses--Entrada',
#   'obsDt': '2025-08-26 09:55',
#   'howMany': 3,
#   'lat': -34.2656225,
#   'lng': -70.4659009,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S269717926'},
#  {'speciesCode': 'blkrai',
#   'comName': 'Black Rail',
#   'sciName': 'Laterallus jamaicensis',
#   'locId': 'L13597216',
#   'locName': 'SN Humedal Río Maipo--Pajonal y lagunas estacionales',
#   'obsDt': '2025-08-25 15:45',
#   'howMany': 3,
#   'lat': -33.6255746,
#   'lng': -71.6253229,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S269567546'},
#  {'speciesCode': 'slbpri1',
#   'comName': 'Slender-billed Prion',
#   'sciName': 'Pachyptila belcheri',
#   'locId': 'L570161',
#   'locName': 'Valparaíso--Pelágico',
#   'obsDt': '2025-08-25 15:00',
#   'howMany': 8,
#   'lat': -33.0008897,
#   'lng': -71.9479179,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S270273322'},
#  {'speciesCode': 'bryfin1',
#   'comName': 'Bright-rumped Yellow-Finch',
#   'sciName': 'Sicalis uropygialis',
#   'locId': 'L693463',
#   'locName': 'Machuca',
#   'obsDt': '2025-08-25 14:30',
#   'howMany': 1,
#   'lat': -22.5996494,
#   'lng': -68.0657423,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S269713232'},
#  {'speciesCode': 'fragul',
#   'comName': "Franklin's Gull",
#   'sciName': 'Leucophaeus pipixcan',
#   'locId': 'L638133',
#   'locName': 'Puerto Montt--Costanera',
#   'obsDt': '2025-08-25 10:04',
#   'howMany': 129,
#   'lat': -41.474366,
#   'lng': -72.9449165,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S269465950'},
#  {'speciesCode': 'whshil1',
#   'comName': 'White-sided Hillstar',
#   'sciName': 'Oreotrochilus leucopleurus',
#   'locId': 'L4791985',
#   'locName': 'Alto del Naranjo',
#   'obsDt': '2025-08-24 09:00',
#   'howMany': 1,
#   'lat': -33.393756,
#   'lng': -70.4519105,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S269367228'},
#  {'speciesCode': 'grekis',
#   'comName': 'Great Kiskadee',
#   'sciName': 'Pitangus sulphuratus',
#   'locId': 'L2379619',
#   'locName': 'Peine',
#   'obsDt': '2025-08-23 11:50',
#   'howMany': 1,
#   'lat': -23.6819838,
#   'lng': -68.0666649,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S269098114'}]

# %%
# Respuesta b

# %% [markdown]
# ### 3.2 Tranformación (1 punto)

# %% [markdown]
# **a) (0.5 pts)** Transforme la columna `obsDt` de string a un objeto de tipo `datetime` únicamente con año, mes y día (YYYY-MM-DD). Luego, agregue las siguientes nuevas columnas:
# * `month` con únicamente el mes del avistamiento (puede dejar el mes como número entero de 1 a 12).
# * `year-month` con el mes y año fecha en formato YYYY-MM

# %%
# Respuesta

# %% [markdown]
# **b) (0.5 pts)** Averigue cómo tranformar su DataFrame de Pandas en un GeoDataFrame de GeoPandas. Para esto, utilice las columnas `lat`y `lng` para generar los puntos de la nueva columna `geometry`. Para las visualizaciones siguientes utilizaremos el Coordinate Reference System (CRS) EPSG 4326 (también llamado [WGS 84](https://es.wikipedia.org/wiki/WGS84)). Asegúrese que sus coordenadas correspondan a este CRS al crear su GeoDataFrame.

# %%
# Respuesta

# %% [markdown]
# ### 3.3 Exploración del dataset (1 punto)
#
# **a) (0.3 pts)** Utilice `geopandas` para leer el archivo `Regional.shp` descargado de BCN. Asegúrese de que su CRS sea el mismo que utilizó en la sección anterior.

# %%
# Respuesta

# %% [markdown]
# **b) (0.7 pts)** Grafique un mapa de Chile con todos los avistamientos de su dataset como puntos en el mapa. Comente: ¿Cómo se distribuyen estos avistamientos? ¿Hay lugares en Chile donde haya una menor densidad de datos? ¿Cuáles?

# %%
# Respuesta

# %% [markdown]
# ### 3.4 Visualización de migraciones (2.5 puntos)
#
# **a) (0.2 pts)** Vamos a inspeccionar los avistamientos de las siguientes 2 especies en particular:
#
# * Run-run [(*Hymenops perspicillatus*)](https://www.avesdechile.cl/171.htm)
# * Dormilona tontita [(*Muscisaxicola maclovianus*)](https://www.avesdechile.cl/043.htm)
#
# Primero, genere dos nuevos dataframes con los avistamientos de cada especie por separado.

# %%
# Respuesta

# %% [markdown]
# **b) (0.8 pts)** Para cada una de estas especies, agrupe los datos según `year-month`. Luego, realice un gráfico que muestre la cantidad de avistamientos en el tiempo, empezando desde enero del 2022 hasta julio de 2025. Responda: ¿cómo varía cantidad de avistamientos para estas dos especies? ¿Cuáles son sus diferencias?

# %%
# Respuesta

# %% [markdown]
# **b) (1 pto)** Grafique en un mapa de Chile la ubicación de cada avistamiento para cada especie mencionada por separado. Utilice el color de cada punto como indicador del mes de avistamiento (columna `month`). Para esto, utilice un **colormap cíclico** para representar los meses del año. Puede utilizar el colormap disponible en la siguiente celda, o bien utilizar otro (siempre y cuando sea cíclico).

# %%
import matplotlib.colors as mcolors
colors = ["coral", "blue", "coral"]
positions = [0, 0.5, 1]

# Creamos un colormap cíclico para representar meses del año
custom_cmap = mcolors.LinearSegmentedColormap.from_list("cyclic_cmap", list(zip(positions, colors)))

# %%
# Respuesta

# %% [markdown]
# **c) (0.5 pts)** Describa las migraciones de estas dos especies. ¿Cómo se diferencian?

# %% [markdown]
# Respuesta
